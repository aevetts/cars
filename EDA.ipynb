# %%
import pandas as pd
import numpy as np

# %%
cars = pd.read_csv('all_car_adverts.csv')

# %%
cols = [cars.columns[i] for i in range(1,len(cars.columns))]
cars = cars.loc[:,cols]

# %%
cars.loc[:,'year'].unique()
# Out:
# array(['2001', '2019', '2000', '1989', '2022', '2018', '2017', '2016',
#        '2013', '2009', '2012', '2011', '2010', '2015', '2014', '2020',
#        '2021', 'Hatchback', 'Convertible', '2008', '2007', '2006', '2003',
#        '2004', '2005', '2002', '1995', '1999', '1998', '1997', '1996',
#        'Saloon', 'SUV', 'Coupe', '1971', '1934', '1960', '1962', '1963',
#        '1965', '1964', '1967', '1988', '1973', '1974', '1984', '1977',
#        '1979', '1978', '1993', '1994', 'Automatic', 'Manual', 'Estate',
#        '1991', '1970', '1955', '1956', '1983', '1959', '1961', '1966',
#        '1986', '1980', '1985', '1987', '1990', '1976', 'MPV', '1992',
#        '1982', '1949', '1953', '1969', '1968', '1972', 'Pickup',
#        'Combi Van', 'Car Derived Van', '1981',
#        'First year road tax included', '1954', '1958', '1940',
#        '101 miles', '32', 'Minibus', 'Camper', '1950', '1957', '1975',
#        '1951', '1937', '1936', '1952', '1079', '1935', '1938'],
#       dtype=object)

# %%
cars.columns
# Out:
# Index(['make', 'model', 'variant', 'car_price', 'car_badges', 'car_title',
#        'car_sub_title', 'car_attention_grabber', 'car_specs', 'car_seller',
#        'car_seller_rating', 'car_seller_location', 'year', 'reg', 'body_type',
#        'miles', 'engine_vol', 'engine_size', 'engine_size_unit',
#        'transmission', 'feul_type', 'num_owner', 'ulez', 'full_service',
#        'part_service', 'part_warranty', 'full_dealership',
#        'first_year_road_tax', 'brand_new', 'finance_available', 'discounted'],
#       dtype='object')

# %%
cars.loc[(cars.make=='Ford') & (cars.model=='Fiesta')]
# Out:
#         make   model              variant  car_price  \
# 186150  Ford  Fiesta               Active    22105.0
# 186151  Ford  Fiesta               Active    22450.0
# 186152  Ford  Fiesta               Active    22778.0
# 186153  Ford  Fiesta               Active    22778.0
# 186154  Ford  Fiesta               Active    23748.0
# ...      ...     ...                  ...        ...
# 199038  Ford  Fiesta  Zetec White Edition     8780.0
# 199039  Ford  Fiesta  Zetec White Edition     8870.0
# 199040  Ford  Fiesta  Zetec White Edition     9060.0
# 199041  Ford  Fiesta                    i     1295.0
# 199042  Ford  Fiesta                    i     1600.0
#
#                                                car_badges    car_title  \
# 186150             'Brand new', 'Part-ex price guarantee'  Ford Fiesta
# 186151                           'Save £455', 'Brand new'  Ford Fiesta
# 186152             'Brand new', 'Part-ex price guarantee'  Ford Fiesta
# 186153             'Brand new', 'Part-ex price guarantee'  Ford Fiesta
# 186154  'Save £977', 'Brand new', 'Part-ex price guara...  Ford Fiesta
# ...                                                   ...          ...
# 199038  'Lower price', 'Finance available', 'Part-ex p...  Ford Fiesta
# 199039                  'Good price', 'Finance available'  Ford Fiesta
# 199040                  'Good price', 'Finance available'  Ford Fiesta
# 199041                                                 ''  Ford Fiesta
# 199042                                                 ''  Ford Fiesta
#
#                                             car_sub_title  \
# 186150              1.0T EcoBoost Active Euro 6 (s/s) 5dr
# 186151              1.0T EcoBoost Active Euro 6 (s/s) 5dr
# 186152  Fiesta Active 5 door 1.0L EcoBoost 100PS FWD 6...
# 186153  FIESTA ACTIVE 5 DOOR 1.0L ECOBOOST 100PS FWD 6...
# 186154     1.0T EcoBoost MHEV Active DCT Euro 6 (s/s) 5dr
# ...                                                   ...
# 199038  1.2 ZETEC WHITE EDITION AUTUMN 5d 81 BHP EURO6...
# 199039                            1.25 82 Zetec White 5dr
# 199040                            1.25 82 Zetec White 3dr
# 199041                                 1.25i 16v Ghia 5dr
# 199042                                   1.25i 16v LX 5dr
#
#                 car_attention_grabber  \
# 186150  Reserve your 2022 build slot!
# 186151  *IN STOCK- DRIVE AWAY TODAY!*
# 186152                            NaN
# 186153                            NaN
# 186154         BUILD SLOTS AVAILABLE!
# ...                               ...
# 199038    LOW ANNUAL MILEAGE+ECO MODE
# 199039   Sat Nav | Rear Sensors | DAB
# 199040  Sat Nav | White Edition | DAB
# 199041          MOT Till 8 march 2023
# 199042       66k 2keys 1 owner aircon
#
#                                                 car_specs  \
# 186150  Hatchback, 1.0L, 100PS, Manual, Petrol, First ...
# 186151  Hatchback, 1.0L, 100PS, Manual, Petrol, First ...
# 186152  Hatchback, 1.0L, Manual, Petrol, First year ro...
# 186153  Hatchback, 1.0L, 100PS, Manual, Petrol, First ...
# 186154  Hatchback, 1.0L, 125PS, Automatic, Petrol Hybr...
# ...                                                   ...
# 199038  2016 (16 reg), Hatchback, 23,000 miles, 1.2L, ...
# 199039  2016 (66 reg), Hatchback, 36,873 miles, 1.25L,...
# 199040  2017 (66 reg), Hatchback, 27,415 miles, 1.25L,...
# 199041  2001 (Y reg), Hatchback, 60,000 miles, 1.25L, ...
# 199042  2002 (02 reg), Hatchback, 66,000 miles, 1.25L,...
#
#                           car_seller  ...  num_owner ulez full_service  \
# 186150            Hendy Ford Fareham  ...        NaN    1            0
# 186151     T C Harrison Peterborough  ...        NaN    1            0
# 186152            Hendy Ford Fareham  ...        NaN    1            0
# 186153            Hendy Ford Fareham  ...        NaN    1            0
# 186154    Hendy Ford Tunbridge Wells  ...        NaN    1            0
# ...                              ...  ...        ...  ...          ...
# 199038                    Reed Autos  ...        2.0    1            0
# 199039  Evans Halshaw Ford Blackpool  ...        NaN    1            0
# 199040  Evans Halshaw Ford Hull East  ...        NaN    1            0
# 199041                      Ldm Cars  ...        2.0    1            0
# 199042     ESSEXTRADECARSANDVANS LTD  ...        1.0    0            0
#
#        part_service part_warranty  full_dealership  first_year_road_tax  \
# 186150            0             1                0                    1
# 186151            0             1                0                    1
# 186152            0             1                0                    1
# 186153            0             1                0                    1
# 186154            0             1                0                    1
# ...             ...           ...              ...                  ...
# 199038            0             0                0                    0
# 199039            0             0                0                    0
# 199040            0             0                0                    0
# 199041            0             0                0                    0
# 199042            0             0                0                    0
#
#         brand_new finance_available discounted
# 186150          1                 0          0
# 186151          1                 0          1
# 186152          1                 0          0
# 186153          1                 0          0
# 186154          1                 0          1
# ...           ...               ...        ...
# 199038          0                 1          0
# 199039          0                 1          0
# 199040          0                 1          0
# 199041          0                 0          0
# 199042          0                 0          0
#
# [12893 rows x 31 columns]

# %%
cars.loc[~cars.year.str[0].isin(['1','2'])].reg.unique()
#The rows with missing years also have missing reg info. Just ditch these rows, there are too many to manually fill (~48k).
# Out:
# array([nan], dtype=object)

# %%
#Remove rows with missing years
carsclean = cars.loc[cars.year.str[0].isin(['1','2'])]

# %%
fiestas = carsclean.loc[(cars.make=='Ford') & (cars.model=='Fiesta')]
fiestas = fiestas.reset_index()

# %%
# Check rows with missing engine volume
fiestas.loc[fiestas.engine_vol.isna(), ['car_sub_title','engine_vol']]
# Out:
#                                            car_sub_title  engine_vol
# 1760   1.0T EcoBoost Titanium Hatchback 5dr Petrol Ma...         NaN
# 2744   1.6T EcoBoost ST-2 Hatchback 3dr Petrol Manual...         NaN
# 2785               1.6T EcoBoost ST-2 With Nav & 330 BHP         NaN
# 2832   1.5T EcoBoost ST-2 Hatchback 3dr Petrol Manual...         NaN
# 3351   ST-3 Hatchback 3dr Petrol Manual Euro 6 (s/s) ...         NaN
# 3372   1.5T EcoBoost ST-3 Hatchback 3dr Petrol Manual...         NaN
# 3519                                                 NaN         NaN
# 3595   1.0T EcoBoost ST-Line Hatchback 3dr Petrol Man...         NaN
# 3941   1.0T EcoBoost GPF ST-Line Hatchback 5dr Petrol...         NaN
# 4616   1.0T EcoBoost ST-Line Edition Hatchback 5dr Pe...         NaN
# 4767   1.0T EcoBoost ST-Line Edition Hatchback 3dr Pe...         NaN
# 5066   ST-LINE X HATCHBACK 3DR (140 PS), SAT NAV, HEA...         NaN
# 6790   1.0T EcoBoost Titanium Hatchback 5dr Petrol Ma...         NaN
# 7866   1.1 Ti-VCT Zetec Hatchback 5dr Petrol Manual E...         NaN
# 9226   1.0T EcoBoost Titanium Hatchback 5dr Petrol Ma...         NaN
# 9290   1.0T EcoBoost Turbo Hatchback 5dr Petrol Manua...         NaN
# 10611  LEFT HAND DRIVE 1.25 Zetec Hatchback 5dr Petro...         NaN
# 10691                                 1.6 TDCi Zetec 5dr         NaN
# 10738                                                NaN         NaN
# 11817                                                NaN         NaN

# %%
# Insert missing engine volume where possible based on car_sub_title
fiestas.loc[1760,'engine_vol'] = 1.0
fiestas.loc[2744,'engine_vol'] = 1.6
fiestas.loc[2785,'engine_vol'] = 1.6
fiestas.loc[2832,'engine_vol'] = 1.5
fiestas.loc[3372,'engine_vol'] = 1.5
fiestas.loc[3595,'engine_vol'] = 1.0
fiestas.loc[3941,'engine_vol'] = 1.0
fiestas.loc[4616,'engine_vol'] = 1.0
fiestas.loc[4767,'engine_vol'] = 1.0
fiestas.loc[6790,'engine_vol'] = 1.0
fiestas.loc[7866,'engine_vol'] = 1.1
fiestas.loc[9226,'engine_vol'] = 1.0
fiestas.loc[9290,'engine_vol'] = 1.0
fiestas.loc[10611,'engine_vol'] = 1.25
fiestas.loc[10691,'engine_vol'] = 1.6

# %%
# Remove remaining rows with missing engine volume
fiestas = fiestas.loc[~fiestas.engine_vol.isna()]

# %%
#Q: is there an automated way of converting seller_location string to a postcode? Or some other broad geographic numerical value so that we can use it as a feature?

#Q: need to split data into training and testing data. Or just test on live autotrader/gumtree/etc entries?

# First things first, set up a regression/NN on year and mileage.

# %%
fiestas.loc[:,'year'].astype('int64')
# Out:
# 0        2022
# 1        2019
# 2        2019
# 3        2019
# 4        2018
#          ...
# 12280    2016
# 12281    2016
# 12282    2017
# 12283    2001
# 12284    2002
# Name: year, Length: 12280, dtype: int64

# %%
fiestas.loc[:,'year'] = fiestas.loc[:,'year'].astype('Int64')

# %%
fiestas.year = fiestas.year.astype('float64')

# %%
fiestasbase = fiestas.loc[:,['year','miles', 'engine_vol','car_price']].copy()

# %%
fiestasbase.dtypes
# Out:
# year          float64
# miles         float64
# engine_vol    float64
# car_price     float64
# dtype: object

# %%
#Need to make sure no NaNs etc.

print(len(fiestasbase.loc[np.isnan(fiestasbase.year)]),
len(fiestasbase.loc[np.isnan(fiestasbase.miles)]),
len(fiestasbase.loc[np.isnan(fiestasbase.car_price)]))
# Out:
# 0 98 0

# %%
fiestasbase = fiestasbase.drop(fiestasbase.loc[np.isnan(fiestasbase.miles)].index)

# %%
# Check that it worked
print(len(fiestasbase.loc[np.isnan(fiestasbase.year)]),
len(fiestasbase.loc[np.isnan(fiestasbase.miles)]),
len(fiestasbase.loc[np.isnan(fiestasbase.car_price)]))
# Out:
# 0 0 0

# %%
# Split into training and testing data
traindata = fiestasbase.sample(frac=0.8, random_state=42)
testdata = fiestasbase.drop(traindata.index)

# %%
fiestas.loc[:,['year','miles','car_price']].plot(x='miles', y='year', c='car_price', legend=True, kind='scatter')
# Out:
# <Axes: xlabel='miles', ylabel='year'>

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# Make NumPy printouts easier to read.
np.set_printoptions(precision=3, suppress=True)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

print(tf.__version__)
# Out:
# 2.20.0

# %%
sns.pairplot(traindata[['year', 'miles', 'car_price']], diag_kind='kde')

# %%
traindata.describe().transpose()
# Out:
#              count          mean           std      min      25%      50%  \
# year        9746.0   2015.502770      4.184415  1980.00   2013.0   2016.0
# miles       9746.0  48526.504515  33609.663187    10.00  19045.5  43200.0
# engine_vol  9746.0      1.181341      0.234265     0.95      1.0      1.0
# car_price   9746.0   9533.132054   5161.075267   475.00   5295.0   8390.0
#
#                  75%       max
# year         2019.00    2022.0
# miles       72731.25  400000.0
# engine_vol      1.40       2.0
# car_price   13699.00   29990.0

# %%
# Split features and labels
trainfeats = traindata.copy()
testfeats = testdata.copy()

trainlabels = trainfeats.pop('car_price')
testlabels = testfeats.pop('car_price')

# %%
trainfeats
# Out:
#          year     miles  engine_vol
# 1947   2020.0   15022.0        1.00
# 3015   2020.0    6691.0        1.50
# 6977   2008.0  108000.0        1.40
# 11605  2013.0   69000.0        1.00
# 4271   2019.0   21001.0        1.00
# ...       ...       ...         ...
# 11355  2012.0   85450.0        1.20
# 9048   2015.0   70312.0        1.60
# 11942  2014.0   58595.0        1.00
# 5579   2009.0   74000.0        1.25
# 5399   2007.0   71000.0        1.40
#
# [9746 rows x 3 columns]

# %%
normalizer = tf.keras.layers.Normalization(axis=-1)
normalizer.adapt(np.array(trainfeats))

# %%
# Define plotting function for loss curves
def plot_loss(history, range):
  plt.plot(history.history['loss'], label='loss')
  plt.plot(history.history['val_loss'], label='val_loss')
  plt.ylim(range)
  plt.xlabel('Epoch')
  plt.ylabel('Error')
  plt.legend()
  plt.grid(True)

# %%
normalizer.mean.numpy()
# Out:
# array([[ 2015.503, 48526.504,     1.181]], dtype=float32)

# %%
first = np.array(trainfeats[:1])
first
# Out:
# array([[ 2020., 15022.,     1.]])

# %%
with np.printoptions(precision=2, suppress=True):
  print('First example:', first)
  print()
  print('Normalized:', normalizer(first).numpy())
# Out:
# First example: [[ 2020. 15022.     1.]]
#
# Normalized: [[ 1.07 -1.   -0.77]]

# %%
# Define plotting function for loss curves
def plot_loss(history, range):
  plt.plot(history.history['loss'], label='loss')
  plt.plot(history.history['val_loss'], label='val_loss')
  plt.ylim(range)
  plt.xlabel('Epoch')
  plt.ylabel('Error')
  plt.legend()
  plt.grid(True)

# Set up normalizer layer
normalizer = tf.keras.layers.Normalization(axis=-1)
normalizer.adapt(np.array(trainfeats))

# %%
# Set up sequential NN
car_model = tf.keras.Sequential([
    normalizer,
    layers.Dense(64, activation='relu'),
    layers.Dense(64, activation='relu'),
    layers.Dense(64, activation='relu'),
    layers.Dense(units=1, activation='relu'),    
])

car_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.05),
    loss='mean_squared_error'
)

# %%
# %%time
history = car_model.fit(
    trainfeats,
    trainlabels,
    epochs=400,
    # Suppress logging.
    verbose=0,
    # Calculate validation results on 20% of the training data.
    validation_split = 0.2
)

#plot_loss(history,[0,10000])
# Out:
# CPU times: total: 6min 48s
# Wall time: 4min 57s

# %%
plot_loss(history, [0,10000000])

# %%
def eval_model(testlabels, predictions):

    y_test = np.array(testlabels)
    y_pred = predictions.flatten()
    residuals = y_test - y_pred


    plt.figure(figsize=(15, 5))

# --- Plot 1: Actual vs Predicted ---
    plt.subplot(1, 3, 1)
    sns.scatterplot(x=y_test, y=y_pred, alpha=0.6)
# Draw the ideal 45-degree line (perfect prediction)
    min_val = min(np.min(y_test), np.min(y_pred))
    max_val = max(np.max(y_test), np.max(y_pred))
    plt.plot([min_val, max_val], [min_val, max_val], 'r--', lw=2)
    plt.title('Actual vs. Predicted')
    plt.xlabel('Actual Price')
    plt.ylabel('Predicted Price')

# --- Plot 2: Residual Plot ---
    plt.subplot(1, 3, 2)
    sns.scatterplot(x=y_pred, y=residuals, alpha=0.6)
    plt.axhline(y=0, color='r', linestyle='--', lw=2) # The zero error line
    plt.title('Residuals vs. Predicted')
    plt.xlabel('Predicted Price')
    plt.ylabel('Residuals (Actual - Predicted)')

    # --- Plot 3: Error Distribution ---
    plt.subplot(1, 3, 3)
    sns.histplot(residuals, kde=True, bins=30)
    plt.axvline(x=0, color='r', linestyle='--', lw=2) # The zero error line
    plt.title('Distribution of Residuals')
    plt.xlabel('Prediction Error')

    plt.tight_layout()
    plt.show()

    print(f'MSE: {(1/len(y_test))*(sum(y_test - y_pred )**2)}' )

# %%
eval_model(testlabels, car_model.predict(testfeats))
# Out:
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# MSE: 1465210.550620681

# %%
# Fewer epochs
car_model2 = tf.keras.Sequential([
    normalizer,
    layers.Dense(64, activation='relu'),
    layers.Dense(64, activation='relu'),
    layers.Dense(64, activation='relu'),
    layers.Dense(units=1, activation='relu'),    
])

car_model2.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.05),
    loss='mean_squared_error'
)

#%%time
history = car_model2.fit(
    trainfeats,
    trainlabels,
    epochs=200,
    # Suppress logging.
    verbose=0,
    # Calculate validation results on 20% of the training data.
    validation_split = 0.2
)

plot_loss(history, [0,10000000])

# %%
eval_model(testlabels, car_model2.predict(testfeats))
# Out:
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# MSE: 2408035.7509108726

# %%
# Even fewer epochs
car_model3 = tf.keras.Sequential([
    normalizer,
    layers.Dense(64, activation='relu'),
    layers.Dense(64, activation='relu'),
    layers.Dense(64, activation='relu'),
    layers.Dense(units=1, activation='relu'),    
])

car_model3.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.05),
    loss='mean_squared_error'
)

#%%time
history = car_model3.fit(
    trainfeats,
    trainlabels,
    epochs=100,
    # Suppress logging.
    verbose=0,
    # Calculate validation results on 20% of the training data.
    validation_split = 0.2
)

plot_loss(history, [0,10000000])

# %%
eval_model(testlabels, car_model3.predict(testfeats))
# Out:
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# MSE: 728237235.430583

# %%
# Just linear
car_model_linear = tf.keras.Sequential([
    normalizer,
    layers.Dense(units=1, activation='relu'),    
])

car_model_linear.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.5),
    loss='mean_squared_error'
)

#%%time
history = car_model_linear.fit(
    trainfeats,
    trainlabels,
    epochs=400,
    # Suppress logging.
    verbose=0,
    # Calculate validation results on 20% of the training data.
    validation_split = 0.2
)

plot_loss(history, [0,10000000])

# %%
eval_model(testlabels, car_model_linear.predict(testfeats))
# Out:
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# MSE: 376884850.524137

# %%
# Linear, larger learning rate
car_model_linear2 = tf.keras.Sequential([
    normalizer,
    layers.Dense(units=1, activation='relu'),    
])

car_model_linear2.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.5),
    loss='mean_squared_error'
)

#%%time
history = car_model_linear2.fit(
    trainfeats,
    trainlabels,
    epochs=400,
    # Suppress logging.
    verbose=0,
    # Calculate validation results on 20% of the training data.
    validation_split = 0.2
)

plot_loss(history, [0,10000000])

eval_model(testlabels, car_model_linear2.predict(testfeats))
# Out:
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
# More layers
car_model_5hl = tf.keras.Sequential([
    normalizer,
    layers.Dense(64, activation='relu'),
    layers.Dense(64, activation='relu'),
    layers.Dense(64, activation='relu'),
    layers.Dense(64, activation='relu'),
    layers.Dense(64, activation='relu'),
    layers.Dense(units=1, activation='relu'),    
])

car_model_5hl.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.05),
    loss='mean_squared_error'
)

#%%time
history = car_model_5hl.fit(
    trainfeats,
    trainlabels,
    epochs=400,
    # Suppress logging.
    verbose=0,
    # Calculate validation results on 20% of the training data.
    validation_split = 0.2
)

plot_loss(history, [0,10000000])

eval_model(testlabels, car_model_5hl.predict(testfeats))
# Out:
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# MSE: 21417414.50207426

# %%
# 5 hidden layers, MAE loss
car_model_5hlmae = tf.keras.Sequential([
    normalizer,
    layers.Dense(64, activation='relu'),
    layers.Dense(64, activation='relu'),
    layers.Dense(64, activation='relu'),
    layers.Dense(64, activation='relu'),
    layers.Dense(64, activation='relu'),
    layers.Dense(units=1, activation='relu'),    
])

car_model_5hlmae.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.05),
    loss='mean_absolute_error'
)

#%%time
history = car_model_5hlmae.fit(
    trainfeats,
    trainlabels,
    epochs=400,
    # Suppress logging.
    verbose=0,
    # Calculate validation results on 20% of the training data.
    validation_split = 0.2
)

plot_loss(history, [0,10000000])

eval_model(testlabels, car_model_5hlmae.predict(testfeats))
# Out:
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
plot_loss(history, [0,10000])

# %%
# Fewer layers
car_model_1hl = tf.keras.Sequential([
    normalizer,
    layers.Dense(64, activation='relu'),
    layers.Dense(units=1, activation='relu'),    
])

car_model_1hl.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.05),
    loss='mean_squared_error'
)

#%%time
history = car_model_1hl.fit(
    trainfeats,
    trainlabels,
    epochs=400,
    # Suppress logging.
    verbose=0,
    # Calculate validation results on 20% of the training data.
    validation_split = 0.2
)

plot_loss(history, [0,10000000])

eval_model(testlabels, car_model_1hl.predict(testfeats))
# Out:
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
# 2 hidden layers
car_model_2hl = tf.keras.Sequential([
    normalizer,
    layers.Dense(64, activation='relu'),
    layers.Dense(64, activation='relu'),
    layers.Dense(units=1, activation='relu'),    
])

car_model_2hl.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.05),
    loss='mean_squared_error'
)

#%%time
history = car_model_2hl.fit(
    trainfeats,
    trainlabels,
    epochs=400,
    # Suppress logging.
    verbose=0,
    # Calculate validation results on 20% of the training data.
    validation_split = 0.2
)

plot_loss(history, [0,10000000])

eval_model(testlabels, car_model_2hl.predict(testfeats))
# Out:
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
